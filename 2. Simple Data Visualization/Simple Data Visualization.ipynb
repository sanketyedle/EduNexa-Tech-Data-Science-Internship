# %% [markdown]
# # Simple Data Visualization
# ## Create a Basic Bar Chart or Line Chart Using a Popular Python Visualization Library Like Matplotlib or Seaborn. Visualize Key Insights From the Dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Basic Dataset Operations

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # Scatter Plot for Sepal Length and Sepal Width

# %%
df.plot(kind='scatter',
		x='sepal_length',
		y='sepal_width',
		color='red')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # Scatter Plot 'Bar'

# %%
df.plot(kind='bar',
		x='sepal_length',
		y='sepal_width',
		color='blue')
# Out:
# <Axes: xlabel='sepal_length'>

# %% [markdown]
# # Pie Plot to Get the Frequency of the Three Species of the IRIS Dataset

# %%
iris = pd.read_csv("IRIS.csv")
ax=plt.subplots(1,1,figsize=(10,8))
iris['species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.title("Iris Species %")
plt.show()

# %% [markdown]
# # Box Plot for IRIS Dataset

# %%
plt.figure(figsize = (10, 7)) 
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # Histogram for Sepal Width

# %%
plt.figure(figsize = (10,10)) 
x = df["sepal_width"] 
  
plt.hist(x, bins = 20, color = "green") 
plt.title("Sepal Widthth in cm") 
plt.xlabel("sepal_wength") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Histogram for Petal Width

# %%
plt.figure(figsize = (10, 7)) 
x = df["petal_width"] 
  
plt.hist(x, bins = 20, color = "blue") 
plt.title("Petal Width in cm") 
plt.xlabel("petal_width") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Histogram for Petal Lenght

# %%
plt.figure(figsize = (10, 7)) 
x = df["petal_length"] 
  
plt.hist(x, bins = 20, color = "red") 
plt.title("Petal Length in cm") 
plt.xlabel("petal_length") 
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Scatter Plot for Petal Length and Petal Width

# %%
df.plot(kind='scatter',
		x='petal_length',
		y='petal_width',
		color='orange')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# # Line Chart Plotting

# %%
plt.figure(figsize=(14,6))
plt.title("IRIS Dataset Infromation")
sns.lineplot(data=df)
# Out:
# <Axes: title={'center': 'IRIS Dataset Infromation'}>

# %% [markdown]
# # Seaborn Jointplot

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=df, size=5)

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x="species", y="sepal_width", palette="husl", data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# # Swarm Plot

# %%
import warnings
warnings.filterwarnings('ignore')
sns.swarmplot(x="species", y="petal_length", data=df, color="blue", alpha=.9);
